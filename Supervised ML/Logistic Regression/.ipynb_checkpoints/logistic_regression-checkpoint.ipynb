# %% [markdown]
# # Logistic Regression
# **Logistic Regression is built from Linear Regression.**
#
#
#
# ---
#
# # Step 1: We start exactly like Linear Regression
#
# First, we calculate a linear equation:
#
# ![image.png](attachment:b5ea7c3f-3ad7-45b8-b0e4-03822b0f4531.png)
#
#
#
# This part is **identical to linear regression.**
#
#
#
# ---
#
# # Step 2: But classification needs probabilities
#
# Suppose we want to predict
#
# Spam or Not Spam
#
# Disease or Healthy
#
# Pass or Fail
#
# We cannot say
#
# "The answer is 7.3"
#
# That makes no sense.
#
# Instead we need something like
#
# Probability = 0.91
#
# or
#
# Probability = 0.12
#
# So we need to convert
#
# [
# z
# ]
#
# into
#
# a number between **0 and 1**.
#
# ---
#
# # Step 3: Sigmoid function does that
#
# So instead of using
#
# [
# z
# ]
#
# directly,
#
# we pass it into the sigmoid function.
#
# ![image.png](attachment:c11e8b9a-f6d1-4620-9440-dcbf6df2fb45.png)
#
# Think of sigmoid as a converter.
#
# ```
# Linear equation
#       ↓
# z = 5
#       ↓
# Sigmoid
#       ↓
# 0.993
# ```
#
# or
#
# ```
# Linear equation
#       ↓
# z = -4
#       ↓
# Sigmoid
#       ↓
# 0.018
# ```
#
# ---
#
# # Step 4: Why sigmoid?
#
# Because no matter what z is,
#
# Sigmoid always produces
#
# [
# 0<g(z)<1
# ]
#
# Examples
#
# | z   | Sigmoid  |
# | --- | -------- |
# | -10 | 0.000045 |
# | -5  | 0.0067   |
# | -2  | 0.119    |
# | 0   | 0.5      |
# | 2   | 0.881    |
# | 5   | 0.993    |
# | 10  | 0.99995  |
#
# So huge negative numbers become close to 0.
#
# Huge positive numbers become close to 1.
#
# ---
#
# # Step 5: The graph
#
# The S-shaped curve is the sigmoid function.
# ![image.png](attachment:0a25257c-19c5-4f78-9721-58edddbc9bf8.png)
# ![image.png](attachment:67681688-e295-4c95-91b9-66ef81687411.png)
#
# ### Sigmoid Curve and Decision Boundary
#
# ![image.png](attachment:dc4f20c8-b6e4-4e5a-a902-19eb8c6b7ccd.png)
#
# Notice
#
# When
#
# [
# z=0
# ]
#
# the output is
#
# [
# g(z)=0.5
# ]
#
#
#
# ---
#
# ## If z > 0
#
# Example
#
# [
# z=4
# ]
#
# Sigmoid
#
# ≈0.982
#
# Very likely Class 1.
#
# ---
#
# ## If z < 0
#
# Example
#
# [
# z=-4
# ]
#
# Sigmoid
#
# ≈0.018
#
# Very likely Class 0.
#
# ---
#
# ## If z = 0
#
# Sigmoid
#
# =0.5
#
# The model is completely uncertain.
#
# ---
#
# # Step 6: Combining everything
#
# ![image.png](attachment:3dec7491-ae11-49c5-869e-fd0a2416cf10.png)
#
# ---
#
# # Step 7:
#
# Instead of one feature,
#
# suppose we have
#
# Age
#
# Income
#
# Experience
#
# Then
#
# ![image.png](attachment:86db4a67-a439-4380-85fe-d4445a9b4c7d.png)
#
# ---
#
# # Step 8: Final prediction
#
# Suppose
#
# ![image.png](attachment:702031d4-882a-477d-9e39-85358cc4f210.png)
#
# This means
#
# **82% probability that the sample belongs to Class 1.**
#
# Now we use a threshold.
#
# Usually
#
# ```
# Probability ≥ 0.5
#         ↓
# Class 1
#
# Probability < 0.5
#         ↓
# Class 0
# ```
#
# So
#
# 0.82 → Class 1
#
# 0.13 → Class 0
#
# ---
#
# The key idea is that **Logistic Regression is still a linear model internally** because it first computes the linear score. The only difference from Linear Regression is that it **passes that score through the sigmoid function** to turn it into a probability that can be used for classification.
#
# ![image.png](attachment:8f4d74a9-4e47-42dc-aea6-4f71be033ef5.png)

# %% [markdown]
# ---
# # Cost Function
#
# ### What is the purpose of a cost function?
#
# Exactly the same as in Linear Regression.
#
# It answers one question:
#
# > **How bad are my predictions?**
#
# If predictions are good,
#
# Cost → small
#
# If predictions are bad,
#
# Cost → large
#
# Then gradient descent tries to make this cost as small as possible.
#
# ---
#
# # Why can't we use Mean Squared Error?
#
# Because logistic regression predicts probabilities (0 to 1), not continuous values.
#
# Using MSE gives a non-convex cost surface, causing gradient descent to get stuck in local minima.
#
# ![image.png](attachment:10f5ce6c-f351-4cfb-b224-1c99f3eba4b9.png)
#
# So we need another cost function.
#
# That cost function is
#
# **Log Loss (Binary Cross Entropy).**
#
# ---
#
# # Think like a teacher grading an exam
#
# Suppose
#
# Actual answer
#
# [
# y=1
# ]
#
#
# Now see different predictions.
#
# | Predicted Probability | Good or Bad?   |
# | --------------------- | -------------- |
# | 0.99                  | Excellent      |
# | 0.90                  | Good           |
# | 0.70                  | Acceptable     |
# | 0.51                  | Barely correct |
# | 0.20                  | Very bad       |
# | 0.01                  | Terrible       |
#
# Should all wrong answers receive the same punishment?
#
# No.
#
# The more confident the model is **while being wrong**, the bigger the punishment should be.
#
# That's exactly what log loss does.
#
# ---
#
# # Case 1
#
# Actual
#
#
# y=1
#
# Cost becomes
#
# -log(y^)
# ![image.png](attachment:ffe429c6-886f-4faa-8bc1-896b9e3b1c56.png)
#
#
# ---
#
# Suppose prediction
#
# y hat= 1
#
# Cost =0
# ![image.png](attachment:f6e4288b-1f1d-44e7-b9ae-c64f46a43d51.png)
#
#
# Perfect prediction.
#
# No punishment.
#
# ---
#
# Prediction
#
#
# y hat =0.9
#
# Cost
#
# ≈0.105
# ![image.png](attachment:f0b0cf40-f970-4562-97e2-db3ff7b76df2.png)
# Tiny punishment.
#
# ---
#
# Prediction
#
# y hat = 0.5
#
# Cost
#
# ≈0.693
#
# Bigger punishment.
#
# ---
#
# Prediction
#
# y hat = 0.1
#
# Cost
#
# ≈2.30
#
# Very large punishment.
#
# ---
#
# Prediction
#
# y hat=0.001
#
# Cost
#
# ≈6.9
#
# Huge punishment.
#
# Because the model was extremely confident and completely wrong.
#
# That is why the graph shoots upward near 0.
# ![image.png](attachment:62aff510-5385-4fc5-b7f6-feb33892e5ca.png)
#
# ---
#
# # Case 2
#
# Suppose
#
# Actual
#
#
# y=0
#
#
# Now we use
# ![image.png](attachment:90e2e4c0-d206-47b1-93c7-67c8f897b691.png)
#
#
# ---
#
# Prediction
#
# 0
#
# Cost
#
# 0
#
# Perfect.
#
# ---
#
# Prediction
#
# 0.1
#
# Very small cost.
#
# ---
#
# Prediction
#
# 0.5
#
# Medium cost.
#
# ---
#
# Prediction
#
# 0.99
#
# Huge cost.
#
# Again,
#
# Very confident
#
# Very wrong
#
# Very large punishment.
#
# ![image.png](attachment:f7c4cfef-27ed-492d-acd8-7b36782d5478.png)
# ---
#
# # Why two different formulas?
#
# Because we have two classes.
#
# When
#
#
# y=1
#
#
# we care about
#
# ![image.png](attachment:bfd39edb-fde7-40f1-962b-081ea280ada5.png)
#
# When
#
#
# y=0
#
#
# we care about
#
# ![image.png](attachment:01c42a11-3e2b-403f-a50c-e2044cff6cc6.png)
#
# Instead of writing an if-else statement in mathematics, both are combined into one equation.
#
# ---
#
# # The combined formula
#
# ![image.png](attachment:6bd803e2-10c5-43b6-a53b-712b67858c5a.png)
#
# It looks scary, but it's just an if-else.
#
# ---
#
# ## If actual class is 1
#
# Then
#
#
# y=1
#
#
# Substitute into the formula.
#
# ![image.png](attachment:e883699b-8726-4e18-b3d5-36fc07edfca4.png)
#
# Second part disappears.
#
# Only
#
# ![image.png](attachment:8b9d180e-4f8f-43f4-ab24-93ead4606c72.png)
#
# remains.
#
# ---
#
# ## If actual class is 0
#
# Then
#
#
# y=0
#
#
# Substitute.
#
# ![image.png](attachment:c5462457-b27c-4b3a-8982-97834947ff62.png)
#
# First part disappears.
#
# Only
#
# ![image.png](attachment:c5f5ff0c-e4c3-4f67-99e1-ee53abcbe779.png)
#
# remains.
#
# So the big equation automatically chooses the correct formula.
#
# ---
#
# # What does the complete cost function do?
#
# Suppose we have 5 training examples.
#
# | Actual | Prediction | Individual Loss |
# | ------ | ---------- | --------------- |
# | 1      | 0.95       | 0.05            |
# | 0      | 0.10       | 0.10            |
# | 1      | 0.80       | 0.22            |
# | 1      | 0.30       | 1.20            |
# | 0      | 0.90       | 2.30            |
#
# The total cost is simply
#
# 1. Compute the loss for each training example.
# 2. Add all the losses.
# 3. Divide by the number of examples (m).
#
# That gives one number:
#
# ![image.png](attachment:6753918f-79cc-47c5-add1-f37931e77842.png)
#
# Gradient descent then changes the parameters thetas to reduce this average loss.
#
# ---
#
# # Finally
#
# The complete training process is
#
# ```
# Training Data
#       │
#       ▼
# Compute z = θᵀx
#       │
#       ▼
# Apply Sigmoid
#       │
#       ▼
# Predicted Probability (ŷ)
#       │
#       ▼
# Compare with Actual Label (y)
#       │
#       ▼
# Calculate Log Loss
#       │
#       ▼
# Average all losses → J(θ)
#       │
#       ▼
# Gradient Descent updates θ
#       │
#       ▼
# Repeat until cost is minimum
# ```
#
# ### One sentence to remember
#
# **Log loss measures how wrong the predicted probability is, and it punishes confident wrong predictions much more severely than uncertain ones.**
