# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[5,6,7,8,8]

#line plot
plt.plot(x,y) 
plt.show()

# %%
# real data
oscar_winners=[
    "The Dark knight",
    "The Heart locker",
    "The king's Speech",
    "The Artist",
    "Argo"
]
years=[2008,2009,2010,2011,2012]
oscar_revenue=[1005,170,427,133,232] #in $M

#plot
plt.plot(years,oscar_revenue)
plt.title("Oscar Movies Revenue in each year")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.show()

# %%
# non_oscar winner movies
non_oscar_movies=["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue=[378,2788,829,185,275] #in $M

#format string
#fmt='[marker][line][color]'
# "o-b"      Blue circles + solid line
# "s--r"     Red squares + dashed line
# "^-g"      Green triangles + solid line
# "x:k"      Black x markers + dotted line
# "*-.m"     Magenta stars + dash-dot line


#plot
plt.plot(years,oscar_revenue,"o-b",label="Oscar Movies")

#we cal also pass values like this: 
#plt.plot(years, oscar_revenue, color=red, marker="o", linestyle="--", linewidth=3, label="Oscar Movies")
# we can also pass hex values if we want

plt.plot(years,non_oscar_revenue,"o-r",label="Non Oscar Movies")
plt.title("Oscar Movies vs Non Oscar Movies Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")
plt.legend( ) #to show the label box of both the lines

plt.show()

# %%
#to show cartoon style graphs
with plt.xkcd():

    plt.plot(years,oscar_revenue,label="Oscar Movies")
    plt.plot(years,non_oscar_revenue,label="Non Oscar Movies")
    
    plt.title("Oscar Movies vs Non Oscar Movies Revenue")
    plt.xlabel("Years")
    plt.ylabel("Revenue (in $M)")
    plt.legend( ) #to show the label box of both the lines
    
    #styles
    print(plt.style.available) #shows all available styles
    
    plt.style.use("default")
    
    #to show grid
    # plt.grid()
    
    
    
    plt.show()

# %%
movies=[
    "The Dark knight",
    "The Heart locker",
    "The king's Speech",
    "The Artist",
    "Argo"
]
years=[2008,2009,2010,2011,2012]
revenue=[1005,170,427,133,232] #in $M

plt.style.use("default")

plt.plot(movies,revenue)
plt.title("Movies revenue")
plt.xlabel("Movies")
plt.ylabel("Revenue in $M")

#spacing issues
plt.tight_layout()

#save fig
plt.savefig("final_plot.png")

plt.show()

# %% [markdown]
# ![image.png](attachment:9964429c-0db2-4474-a1e3-342f24e3c356.png)

# %%
#bar charts
# A bar plot (or bar chart) is a graph that displays categorical data using rectangular bars.
# Each bar's height (or length, in horizontal bars) represents a value.

# %%
movies=[
    "The Dark knight",
    "The Heart locker",
    "The king's Speech",
    "The Artist",
    "Argo"
]
years=[2008,2009,2010,2011,2012]
revenue=[1005,170,427,133,232] #in $M

plt.style.use("default")

plt.bar(years,revenue,color="green")
plt.title("Revenue in each year for Oscar Movies")
plt.xlabel("Year")
plt.ylabel("Revenue in $M")

#plt.text to show value on each bar
#plt.text(x-axis pos, y-axis pos, text, alignment)

for i in range(len(years)):
    plt.text(years[i],oscar_revenue[i]+20,str(oscar_revenue[i]),ha="center")

# to increase x or y limits
plt.ylim(0,max(revenue)+100)

plt.show()

# %%
import numpy as np

# Bar chart: compare two sets of data
oscar_movies=[
    "The Dark knight",
    "The Heart locker",
    "The king's Speech",
    "The Artist",
    "Argo"
]
oscar_revenue=[1005,170,427,133,232] #in $M

non_oscar_movies=["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue=[378,2788,829,185,275] #in $M

years=[2008,2009,2010,2011,2012]

x=np.arange(len(years))
width=0.4

# x-width/2=x-0.2
# x+width/2=x+0.2

plt.bar(x-width/2,oscar_revenue,width,label="Oscar Movies") #shifting to left
plt.bar(x+width/2,non_oscar_revenue,width,label="Non Oscar Movies") #shifting to right
plt.title("Oscar vs Non oscar Movies Revenue")
plt.xlabel("Year")
plt.ylabel("Revenue in $M")

plt.legend()

#replace x values(1,2,3..) with year values now
plt.xticks(x,years)

plt.show()

# %%
#horizontal bar charts

oscar_movies=[
    "The Dark knight",
    "The Heart locker",
    "The king's Speech",
    "The Artist",
    "Argo"
]
oscar_revenue=[1005,170,427,133,232] #in $M

years=[2008,2009,2010,2011,2012]

plt.barh(oscar_movies,oscar_revenue)
plt.xlabel("revenue")
plt.ylabel("movie names")

plt.show()

# %%
# Scatter Plots
# A scatter plot shows the relationship between two variables by plotting points on a 2D plane.

people = ["Person A", "Person B", "Person C", "Person D", "Person E",
"Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

#customizations
# color, size, marker, transparency, colormap

colors=["green" if x<=130 else "red" for x in bp]
#plt.scatter(..,..,.., color=colors)



#colormap
#plt.scatter(..,..,.., cmap="plasma",c=bp)

plt.scatter(age,bp,   cmap="OrRd",c=bp,s=bp,marker="o",alpha=.8) #alpha = transparency. default 1
plt.title("Age vs BP")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid()
plt.colorbar(label="BP")

# annotations
# plt.annotate( "text", xy=(x_point, y_point), xytext=(x_text, y_text) )
for i in range(len(people)):
    plt.annotate(people[i],xy=(age[i],bp[i]), xytext=(age[i]+2,bp[i]-0.5))

plt.xlim(min(age),max(age)+10)
plt.ylim(min(bp),max(bp)+5)
plt.show()

# %%
#Multiple plots 

cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature (℃) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

plt.scatter(winter_temp,winter_humidity,label="Winter",color="blue")
plt.scatter(summer_temp,summer_humidity,label="Summer",color="red")
plt.title("Summer vs Winter Data")
plt.xlabel("Temprature")
plt.ylabel("Humidity %")

plt.legend()
plt.show()

# %%
#Pie charts
# A pie chart is a circular chart divided into slices to show relative proportions of a whole.
# . Each slice = a category
# . Size of slice = value of that category relative to total

# Prefer them only for few categories. 5 or 6

expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]

explode=[0,0,0,.1,0]

plt.pie(amounts,labels=expenses,autopct="%1.1f%%",
        wedgeprops={
    "edgecolor":"black",
    "linewidth":1,
    "linestyle":"-",
    # "fill":False
    
},
        explode=explode,
        startangle=180,
        shadow=True
       )

plt.savefig("piechart.png")

plt.show()

# %% [markdown]
# ![image.png](attachment:6e3686d4-c96e-4fed-87b6-37b209cf9f34.png)
